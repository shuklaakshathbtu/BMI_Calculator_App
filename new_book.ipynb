# %% [markdown]
# <a href="https://colab.research.google.com/github/shuklaakshathbtu/BMI_CALCULATOR_APP/blob/master/new_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt

# %%
df=pandas.read_csv("/content/data.csv")
df.head(3)
# Out:
#           isbn13      isbn10         title subtitle  \
# 0  9780002005883  0002005883        Gilead      NaN
# 1  9780002261982  0002261987  Spider's Web  A Novel
# 2  9780006163831  0006163831  The One Tree      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# ...

# %%
df.shape
# Out:
# (1508, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          1508 non-null   int64
#  1   isbn10          1508 non-null   object
#  2   title           1508 non-null   object
#  3   subtitle        508 non-null    object
#  4   authors         1502 non-null   object
#  5   categories      1492 non-null   object
#  6   thumbnail       1465 non-null   object
#  7   description     1479 non-null   object
#  8   published_year  1505 non-null   float64
#  9   average_rating  1495 non-null   float64
#  10  num_pages       1495 non-null   float64
#  11  ratings_count   1495 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 141.5+ KB

# %%
df.isnull().sum()
# Out:
# isbn13               0
# isbn10               0
# title                0
# subtitle          1000
# authors              6
# categories          16
# thumbnail           43
# description         29
# published_year       3
# average_rating      13
# num_pages           13
# ratings_count       13
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_duplicate=df

# %% [markdown]
# # Deleting Columns
#
#
# *   subtitle
# *   ratings_count
# *   num_pages
# *   average_rating
# *   published_year
# *   thumbnail
# *   isbn13
# *   isbn10

# %%
df=df.drop(['subtitle','ratings_count','num_pages','average_rating','published_year','thumbnail','isbn13','isbn10'], axis=1)

# %%
df.head(2)
# Out:
#           title                          authors  \
# 0        Gilead               Marilynne Robinson
# 1  Spider's Web  Charles Osborne;Agatha Christie
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
#
#                                          description
# 0  A NOVEL THAT READERS and critics have been eag...
# 1  A new 'Christie for Christmas' -- a full-lengt...

# %%
df.isnull().sum()
# Out:
# title            0
# authors         72
# categories      99
# description    262
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# title          0
# authors        0
# categories     0
# description    0
# dtype: int64

# %%
df.head(3)
# Out:
#           title                          authors  \
# 0        Gilead               Marilynne Robinson
# 1  Spider's Web  Charles Osborne;Agatha Christie
# 2  The One Tree             Stephen R. Donaldson
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2               American fiction
#
#                                          description
# 0  A NOVEL THAT READERS and critics have been eag...
# 1  A new 'Christie for Christmas' -- a full-lengt...
# 2  Volume Two of Stephen Donaldson's acclaimed se...

# %%
df['authors'] = df['authors'].astype(str)

# %%
df['authors']=df['authors'].apply(lambda x:x.split(';'))

# %%
df['authors']=df['authors'].apply(lambda x: [i.replace(" ","") for i in x])

# %%
df.head(2)
# Out:
#           title                           authors  \
# 0        Gilead               [MarilynneRobinson]
# 1  Spider's Web  [CharlesOsborne, AgathaChristie]
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
#
#                                          description
# 0  A NOVEL THAT READERS and critics have been eag...
# 1  A new 'Christie for Christmas' -- a full-lengt...

# %%
df.head(2)
# Out:
#           title                             authors  \
# 0        Gilead                [Marilynne Robinson]
# 1  Spider's Web  [Charles Osborne, Agatha Christie]
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
#
#                                          description
# 0  A NOVEL THAT READERS and critics have been eag...
# 1  A new 'Christie for Christmas' -- a full-lengt...

# %%
df['categories'] = df['categories'].astype(str)
df['description'] = df['description'].astype(str)

# %%
df['categories']=df['categories'].apply(lambda x:x.split())

# %%
df['description']=df['description'].apply(lambda x:x.split())

# %%
df.head(2)
# Out:
#           title                           authors  \
# 0        Gilead               [MarilynneRobinson]
# 1  Spider's Web  [CharlesOsborne, AgathaChristie]
#
#                            categories  \
# 0                           [Fiction]
# 1  [Detective, and, mystery, stories]
#
#                                          description
# 0  [A, NOVEL, THAT, READERS, and, critics, have, ...
# 1  [A, new, 'Christie, for, Christmas', --, a, fu...

# %%
df['tags']=df['authors'] + df['categories'] + df['description']

# %%
df=df.drop(['authors','categories','description'], axis=1)

# %%
df.head(3)
# Out:
#           title                                               tags
# 0        Gilead  [MarilynneRobinson, Fiction, A, NOVEL, THAT, R...
# 1  Spider's Web  [CharlesOsborne, AgathaChristie, Detective, an...
# 2  The One Tree  [StephenR.Donaldson, American, fiction, Volume...

# %%
new_df=df

# %%
new_df['tags']=new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head(2)
# Out:
#           title                                               tags
# 0        Gilead  marilynnerobinson fiction a novel that readers...
# 1  Spider's Web  charlesosborne agathachristie detective and my...

# %%
new_df['tags'][0]
# Out:
# 'marilynnerobinson fiction a novel that readers and critics have been eagerly anticipating for over a decade, gilead is an astonishingly imagined story of remarkable lives. john ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. it’s 1956 in gilead, iowa, towards the end of the reverend ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. haunted by his grandfather’s presence, john tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. he is troubled, too, by his prodigal namesake, jack (john ames) boughton, his best friend’s lost son who returns to gilead searching for forgiveness and redemption. told in john ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, gilead is a song of celebration and acceptance of the bes
# ...

# %%
new_df['tags'][1]
# Out:
# "charlesosborne agathachristie detective and mystery stories a new 'christie for christmas' -- a full-length novel adapted from her acclaimed play by charles osborne following black coffee and the unexpected guest comes the final agatha christie play novelisation, bringing her superb storytelling to a new legion of fans. clarissa, the wife of a foreign office diplomat, is given to daydreaming. 'supposing i were to come down one morning and find a dead body in the library, what should i do?' she muses. clarissa has her chance to find out when she discovers a body in the drawing-room of her house in kent. desperate to dispose of the body before her husband comes home with an important foreign politician, clarissa persuades her three house guests to become accessories and accomplices. it seems that the murdered man was not unknown to certain members of the house party (but which ones?), and the search begins for the murderer and the motive, while at the same time trying to persuade a po
# ...

# %% [markdown]
# # Approach
# text will be converted to vectors called as text vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
vectors.shape
# Out:
# (6446, 5000)

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
  y=[]
  for i in text.split():
    y.append(ps.stem(i))
  return " ".join(y)

# %%
new_df['tags']=new_df['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
cosine_similarity(vectors).shape
# Out:
# (1467, 1467)

# %%
def recommend(book):
  book_index=new_df[new_df['title'] == book].index[0]
  distances=similarity[book_index]
  book_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

  for i in book_list:
    print(new_df.iloc[i[0]].title)

# %%
recommend('Gilead')
# Out:
# Go Tell it on the Mountain
# Vanity Fair
# The Chaneysville Incident
# The Deep End of the Ocean
# The Fourteen Sisters of Emilio Montez O'Brien
